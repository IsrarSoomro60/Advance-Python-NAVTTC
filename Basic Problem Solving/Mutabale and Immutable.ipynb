# %% [markdown]
# ## Mutable and Immutable

# %%
data = "hello world "
print(data.strip(" "))
# Out:
# hello world

# %%
lang = "I like java"
print(lang.replace("java", "Python"))
print(lang.replace(" ", ""))
# Out:
# I like Python
# Ilikejava

# %%
words= ["I", "love", "Python"]
print("".join(words))
# Out:
# IlovePython

# %%
fvrt = "I love Python"
print(fvrt.split())
print(fvrt.split("v"))
# Out:
# ['I', 'love', 'Python']
# ['I lo', 'e Python']
