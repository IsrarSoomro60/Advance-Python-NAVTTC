# %% [markdown]
# ## Qno.1

# %%
##1
lang = "hello world"
print(lang.upper())
# Out:
# HELLO WORLD

# %%
##2
lang = "python is fun"
print(lang[0:6].upper())
# Out:
# PYTHON

# %% [markdown]
# ## Qno.2

# %%
##1
lang = "HELLO PYTHON"
print(lang.lower())
# Out:
# hello python

# %%
##2
lang = "python programming"
print(lang[7:].upper())
# Out:
# PROGRAMMING

# %% [markdown]
# ## Qno.3

# %%
##1
fruit = "banana"
print(fruit.count("a"))
# Out:
# 3

# %%
##2
text= "This is Python"
print(fruit.count(" is "))
# Out:
# 0

# %% [markdown]
# ## Qno.4

# %%
##1
ai = " openai "
print(ai.strip(" "))
# Out:
# openai

# %%
##2
ai = "***python***"
print(ai.strip("*"))
# Out:
# python

# %% [markdown]
# ## Qno.5

# %%
##1
lang= "I love Java"
print(lang.replace("Java","Python"))
# Out:
# I love Python

# %%
##2
um = "111223344"
print(num.replace("1","X"))
# Out:
# XXX223344

# %% [markdown]
# ## Qno.6

# %%
##1
lan = ["AI", "ML", "DL"]
print(",".join(lan))
# Out:
# AI,ML,DL

# %%
##2
lan = ["OpenAI", "Chatgpt", "Python"]
print("-".join(lan))
# Out:
# OpenAI-Chatgpt-Python

# %% [markdown]
# ## Qno.7

# %%
##1
fvrt = "I love python programming"
print(fvrt.split())
# Out:
# ['I', 'love', 'python', 'programming']

# %%
##2
fruits = "apple, banana, mango"
print(fruits.split(","))
# Out:
# ['apple', ' banana', ' mango']

# %% [markdown]
# ## Qno.8

# %%
##1
lang1 = "I am learning Python Programming"
print(lang[14:20])

# %%
##2
lang = "OpenAi"
print(lang[-3:])
# Out:
# nAi

# %%
lang1.find("Python")
# Out:
# 14

# %%
lang1.index("Python")
# Out:
# 14
